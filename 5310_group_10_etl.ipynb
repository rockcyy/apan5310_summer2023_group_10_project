# %% [markdown]
# ## ETL

# %%
import pandas as pd
import numpy as np
import random
from sqlalchemy import create_engine

# %%
# Pass the connection string to a variable, conn_url
conn_url = 'postgresql://postgres:123@localhost/5310_project'

# Create an engine that connects to PostgreSQL server
engine = create_engine(conn_url)

# Establish a connection
connection = engine.connect()

# %%
# Load data from the CSV files into DataFrames
car_rental_data = pd.read_csv("CarRentalDataV1.csv")
flight_data = pd.read_csv("flights.csv")
hotel_booking_data = pd.read_csv("hotel_booking.csv")

# %%
car_rental_data
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0     ELECTRIC    5.00              13.0         12.0       Seattle
# 1     ELECTRIC    5.00               2.0          1.0       Tijeras
# 2       HYBRID    4.92              28.0         24.0   Albuquerque
# 3     GASOLINE    5.00              21.0         20.0   Albuquerque
# 4     GASOLINE    5.00               3.0          1.0   Albuquerque
# ...        ...     ...               ...          ...           ...
# 5846  GASOLINE    5.00              32.0         27.0      Honolulu
# 5847    HYBRID    5.00              17.0         16.0          Aiea
# 5848  GASOLINE    4.94              18.0         17.0        Kailua
# 5849  GASOLINE     NaN               1.0          0.0       Waipahu
# 5850  GASOLINE    5.00              16.0         14.0        Kailua
#
#      location.country  location.latitude  location.longitude location.state  \
# ...

# %%
flight_data
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      2008      1           3          4   2003.0        1955   2211.0
# 1      2008      1           3          4    754.0         735   1002.0
# 2      2008      1           3          4    628.0         620    804.0
# 3      2008      1           3          4    926.0         930   1054.0
# 4      2008      1           3          4   1829.0        1755   1959.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
hotel_booking_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Account table

# %%
account_data = pd.read_csv("account_gpt.csv")
account_data.to_sql(name='account', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Address table

# %%
address_data = pd.read_csv("address_gpt.csv")
address_data.to_sql(name='address', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Customer table

# %%
customer_data = hotel_booking_data[['name','phone-number','email']].drop_duplicates()
customer_data['first_name'] = customer_data['name'].str.split(' ').str.get(0)
customer_data['last_name'] = customer_data['name'].str.split(' ').str.get(1)
customer_data = customer_data.rename({'phone-number':'phone'},axis = 1)
customer_data = customer_data.drop('name',axis = 1)
customer_data.insert(0, 'customer_id', range(1, 1 + len(customer_data)))

#randomly assign address to different customers
customer_data['address'] = np.random.randint(1, 51, customer_data.shape[0])

customer_data.to_sql(name='customer', con=engine, if_exists='append', index=False)
# Out:
# 390

# %% [markdown]
# ### Payment table

# %%
payment_data = pd.read_csv("payment_gpt.csv")
payment_data.to_sql(name='payment', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Booking table

# %%
booking_data = pd.read_csv("booking_gpt.csv")
booking_data.to_sql(name='booking', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Vehicle table

# %%
vehicle_data = car_rental_data[['vehicle.make','vehicle.model','vehicle.year']].drop_duplicates()
vehicle_data = vehicle_data.rename({'vehicle.make':'brand','vehicle.model':'model','vehicle.year':'year'},axis = 1)

#generate random hourly rate for renting a vehicle
vehicle_data['hourly_rate'] = np.around(np.random.uniform(10, 100, vehicle_data.shape[0]),2)

#change year column to int type
vehicle_data['year'] = vehicle_data['year'].astype(int)

vehicle_data.insert(0, 'vehicle_id', range(1, 1 + len(vehicle_data)))

vehicle_data.to_sql(name='vehicle', con=engine, if_exists='append', index=False)
# Out:
# 923

# %% [markdown]
# ### Car_rental_company table

# %%
car_rental_company_data = pd.read_csv("car_rental_company_gpt.csv")
car_rental_company_data.to_sql(name='car_rental_company', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Car_rental_order table

# %%
car_rental_order_data = pd.read_csv("car_rental_order_gpt.csv")
car_rental_order_data.to_sql(name='car_rental_order', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Booking_car_rental_order table

# %%
booking_car_rental_order_data = pd.read_csv("booking_car_rental_order_gpt.csv")
booking_car_rental_order_data.to_sql(name='booking_car_rental_order', con=engine, if_exists='append', index=False)
# Out:
# 20

# %% [markdown]
# ### Airline company table

# %%
airline_company_data = flight_data['UniqueCarrier'].drop_duplicates()
airline_company_data
# Out:
# 0        WN
# 94055    XE
# Name: UniqueCarrier, dtype: object

# %%
#WN stands for Southwest Airlines and XE stands for ExpressJet Airlines
airline_company_data = pd.DataFrame({
    'airline_company_id': [1, 2],
    'airline_company_name': ['Southwest Airlines', 'ExpressJet Airlines']
})
airline_company_data.to_sql(name='airline_company', con=engine, if_exists='append', index=False)
# Out:
# 2

# %% [markdown]
# ### Ticket table

# %%
#combine columns to generate the departure and arrival timestamp
ticket_data = flight_data[['Year','Month','DayofMonth','DepTime','ArrTime','UniqueCarrier','FlightNum']].dropna()

ticket_data['DepTime'] = ticket_data['DepTime'].astype(int)
ticket_data['ArrTime'] = ticket_data['ArrTime'].astype(int)

def format_time(year, month, day, time):
    time_str = str(time).zfill(4)
    return f"{year}-{month:02d}-{day:02d} {time_str[:2]}:{time_str[2:]}"

ticket_data['departure_time'] = ticket_data.apply(lambda row: format_time(row['Year'], row['Month'], row['DayofMonth'], row['DepTime']), axis=1)
ticket_data['arrival_time'] = ticket_data.apply(lambda row: format_time(row['Year'], row['Month'], row['DayofMonth'], row['ArrTime']), axis=1)

def airline_company_id(x):
    if x == 'WN':
        return 1
    else:
        return 2

ticket_data['airline_company'] = ticket_data['UniqueCarrier'].apply(airline_company_id)

#combine columns to generate flight number
ticket_data['flight_number'] = ticket_data['UniqueCarrier'] + ticket_data['FlightNum'].astype(str)

ticket_data = ticket_data[['flight_number','departure_time','arrival_time','airline_company']]

#randomly assign seat number
rows = 50
seats_per_row = ['A', 'B', 'C', 'D', 'E', 'F']
all_seats = [f'{i}{seat}' for i in range(1, rows + 1) for seat in seats_per_row]
random.shuffle(all_seats)
ticket_data['seat_number'] = ticket_data['flight_number'].apply(lambda x: random.choice(all_seats))

#randomly assign ticket price
ticket_data['ticket_price'] = np.around(np.random.uniform(10, 100, ticket_data.shape[0]),2)

#randomly assign departure and arrival address
ticket_data['arrival_airport_address'] = np.random.randint(1, 50, ticket_data.shape[0])
ticket_data['departure_airport_address'] = np.random.randint(1, 50, ticket_data.shape[0])

ticket_data.insert(0, 'ticket_id', range(1, 1 + len(ticket_data)))
ticket_data.to_sql(name='ticket', con=engine, if_exists='append', index=False)
# Out:
# 698

# %% [markdown]
# ### Booking_ticket table

# %%
booking_ticket_data = pd.read_csv("booking_ticket_gpt.csv")
booking_ticket_data.to_sql(name='booking_ticket', con=engine, if_exists='append', index=False)
# Out:
# 19

# %% [markdown]
# ### Hotel table

# %%
hotel_data = hotel_booking_data['hotel'].drop_duplicates()
hotel_data
# Out:
# 0        Resort Hotel
# 40060      City Hotel
# Name: hotel, dtype: object

# %%
hotel_data = pd.DataFrame({
    'hotel_id': [1, 2],
    'hotel_name': ['Resort Hotel', 'City Hotel'],
    'hotel_address': [23,24]
})
hotel_data.to_sql(name='hotel', con=engine, if_exists='append', index=False)
# Out:
# 2

# %% [markdown]
# ### Hotel_order table

# %%
hotel_order_data = pd.read_csv("hotel_order_gpt.csv")
hotel_order_data.to_sql(name='hotel_order', con=engine, if_exists='append', index=False)
# Out:
# 50

# %% [markdown]
# ### Booking_hotel_order table

# %%
booking_hotel_order_data = pd.read_csv("booking_hotel_order_gpt.csv")
booking_hotel_order_data.to_sql(name='booking_hotel_order', con=engine, if_exists='append', index=False)
# Out:
# 20

# %% [markdown]
# ### Booking_customer table

# %%
booking_customer_data = pd.read_csv("booking_customer_gpt.csv")
booking_customer_data.to_sql(name='booking_customer', con=engine, if_exists='append', index=False)
# Out:
# 50
